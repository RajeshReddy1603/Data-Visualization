# %%
import matplotlib.pyplot as plt
a=[99,78]
b=[88,100]
plt.title("bar graph")
plt.xlabel("vertical")
plt.ylabel("horzontial")
plt.plot(a,b,marker="*")

# %%
import matplotlib.pyplot as plt
a=[56,89,11]
b=[78,89,99]
plt.title("data visulazation")
plt.xlabel("a axis")
plt.ylabel("b axis")
plt.plot(a,b,marker="*")

# %%
import matplotlib.pyplot as plt
a=[29,78,99]
b=[67,89,100]
c=[89,99,100]
plt.title("its is a graph")
plt.xlabel("a axis")
plt.ylabel("b axis")
plt.plot(a,b,marker="*")
plt.plot(b,c,marker="*")

# %%
import matplotlib.pyplot as plt
a=[34,89,100]
b=[78,89,100]
c=[56,89,98]
plt.title("data visulazation")
plt.xlabel("horzontial")
plt.ylabel("vertical")
plt.plot(a,b,marker="*")
plt.plot(b,c,marker="*")

# %%
import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"]

sales = [23, 45, 56, 78, 213, 45, 78, 89, 99, 100, 101, 130]
plt.title("bar graph")
plt.xlabel("horzontial")
plt.ylabel("vertical")
plt.bar(months,sales)
# Out:
# <BarContainer object of 12 artists>

# %%
import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"]

sales = [23, 45, 56, 78, 213, 45, 78, 89, 99, 100, 101, 130]
plt.title("bar graph")
plt.xlabel("horzontial")
plt.ylabel("vertical")
plt.barh(months,sales)
# Out:
# <BarContainer object of 12 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("sales31.csv")
df
# Out:
#    ord id   cust name  cust id                   prod name  prod cost
# 0  192837       Veeru        3                   LG Mobile      65999
# 1  192838     Neelima       19        Apple iPad 10.2-inch      63000
# 2  192839      Balaji       12      34in Ultrawide Monitor      75999
# 3  192840      Shahid       20                   iPhone 11      60000
# 4  192841       Vinay       10  Bose SoundSport Headphones      69999
# 5  192842       Vinay       10                20in Monitor      65999
# 6  192843      Balaji       12                    iPhone 8      55999
# 7  192844  Nireekshan        1      27in 4K Gaming Monitor      55999
# 8  192845        Venu       23                    iPhone 9      55999
# 9  192846       Veeru        3                20in Monitor      63000

# %%
plt.title("bar graph")
plt.xlabel("cust name")
plt.ylabel("prod cost")
plt.bar(df["cust name"],df["prod cost"])
# Out:
# <BarContainer object of 10 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("sales1.csv")
df.head(2)
# Out:
#    Order ID Customer Name                 Product  Quantity
# 0    166837         Veeru  34in Ultrawide Monitor         2
# 1    166838         Tarun             Samsung m10         3

# %%
plt.title("bar graph")
plt.xlabel("Product")
plt.ylabel("Quantity")
plt.barh(df["Product"],df["Quantity"])
# Out:
# <BarContainer object of 600 artists>

# %%
import pandas as pd
df=pd.read_csv("sales31.csv")
df.head(2)
# Out:
#    ord id cust name  cust id             prod name  prod cost
# 0  192837     Veeru        3             LG Mobile      65999
# 1  192838   Neelima       19  Apple iPad 10.2-inch      63000

# %%
plt.title("bar graph")
plt.xlabel("cust name")
plt.ylabel("prod cost")
plt.bar(df["cust name"],df["prod cost"],width=1.0)
# Out:
# <BarContainer object of 10 artists>

# %%
import matplotlib.pyplot as plt
x=[10,100,None]
y=[20,200,110]
plt.title("plot graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot(x,y,marker="d")
